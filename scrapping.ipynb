# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs4

# %% [markdown]
# ### Scrapping Beberapa Web

# %%
promo_page = requests.get("https://www.bola.com/ragam/read/4526960/45-kata-kata-promosi-berbagai-bisnis-simple-dan-gampang-memancing-konsumen").text
promo_page_second = requests.get("https://finance.detik.com/solusiukm/d-6286621/50-contoh-tulisan-dan-kata-kata-promo-menarik-dan-efektif").text
promo_page_third = requests.get("https://everpro.id/blog/kata-kata-promosi-makanan/").text
promo_page_fourth = requests.get("https://www.thecronutproject.com/kata-kata-promosi-makanan/").text
promo_page_fifth = requests.get("https://www.bola.com/ragam/read/4439815/35-kata-kata-promosi-simple-efektif-dan-menarik-konsumen").text
promo_page_sixth = requests.get("https://www.merdeka.com/jateng/50-kata-kata-promosi-instagram-singkat-tapi-menarik-kln.html").text
promo_page_seventh = requests.get("https://plus.kapanlagi.com/68-kumpulan-kata-kata-promosi-yang-kreatif-dan-informatif-untuk-menarik-perhatian-konsumen-59a78c.html").text
promo_page_eigth = requests.get("https://www.intipseleb.com/gaya-hidup/40521-kumpulan-kata-kata-promosi").text
promo_page_ninth = requests.get("https://www.merdeka.com/trending/50-kata-kata-promosi-makanan-penting-diketahui-agar-konsumen-tertarik-kln.html").text
promo_page_tenth = requests.get("https://kirim.email/contoh-kata-kata-promosi/").text
promo_page_eleventh = requests.get("https://portal-uang.com/promosi/kata-kata/makanan/").text
promo_page
# Out:
# '<!DOCTYPE html><html lang="id" itemscope="itemscope" itemtype="https://schema.org/WebPage"><head><title>45 Kata-Kata Promosi Berbagai Bisnis, Simple dan Gampang Memancing Konsumen - Ragam Bola.com</title><meta charset="utf-8"><meta name="viewport" content="width=1024"><meta name="adx:sections" content="ragam"><meta name="title" content="45 Kata-Kata Promosi Berbagai Bisnis, Simple dan Gampang Memancing Konsumen - Ragam Bola.com"><meta name="description" content="Berikut ini kumpulan kata-kata promosi berbagai macam bisnis yang simple dan bisa menarik konsumen."><meta name="keywords" content="kata, Artikel Bola, Kata-Kata Promosi Makanan, kata-kata promosi, kata-kata, Sportylife"><meta content="index,follow" name="googlebot-news">\n<meta content="index,follow" name="googlebot">\n<meta name="robots" content="index,follow">\n<meta content="Bola.com" name="author">\n<meta content="In-Id" http-equiv="content-language">\n<meta content="id" name="language">\n<meta content="id" name="geo.co
# ...

# %% [markdown]
# ### Pembersihan Data Web Pertama

# %%
update_promo_page = bs4(promo_page, "lxml")
promo_words = update_promo_page.find_all('p')
promo_words
# Out:
# [<p class="authentication--popup__info"></p>,
#  <p class="navbar--top--logo__site-title" data-cache-key="https_bola.com:bump:2b8c8e876424ff8e4b79f97bad45acf5::top-logo-logo::0" data-cache-ttl="120" data-component-name="desktop:navbar:top:logo" itemprop="name"><meta content="https://cdn0-production-assets-kly.akamaized.net/logos/417/original/040683700_1672974475-bolacom.png" itemprop="logo"/><meta content="https://www.bola.com" itemprop="url"/><a class="navbar--top--logo__link" href="https://www.bola.com" itemprop="url"><img alt="logo" class="navbar--top--logo__image" src="https://cdn0-production-assets-kly.akamaized.net/logos/417/original/040683700_1672974475-bolacom.png"/>bola</a></p>,
', 'Bagi orang yang akan berkecimpung di dunia bisnis, tak boleh sembarangan dalam memuat promosi produk. Sebab, kesalahan dalam membuat promosi bisa membuat konsumen tidak percaya dengan produk yang kamu jual.', 'Nah, bagi kamu yang bingung menyusun kata-kata promosi tak perlu resah, sebab banyak\xa0kata-kata promosi yang bisa dijadikan referensi.', 'Berikut ini kumpulan kata-kata promosi yang bisa menarik konsumen dan pelanggan, seperti dilansir dari laman UkmSumut, Selasa (22/12/2020).\xa0', 'Sumber:\xa0Ukmsumut', 'Dapatkan artikel kata-kata dari berbagai tema lainnya dengan mengunjungi tautan ini.']

# Getting Needed Words
targets = [promo_word.text for promo_word in promo_words if promo_word.text not in unneeded_words]

# Array of Result
result = []

# Update Words
for target in targets:
    result.append((target.split(": ", )[1]))

# Result
result
# Out:
# ['Beli 4 ayam penyet, cuma bayar 3 setiap hari Jumat. Beli sekarang juga!',
#  'Beli banyak lebih hemat! Diskon sampai 35% dengan minimal beli Rp 40.000 Kopi Kenangan',
#  'Yuk bunda siapkan berbagai Frozen Food dari RayaFood di rumah agar anak enggak sulit makan lagi',
#  'Rasa masakan Padang yang tidak pernah kamu temukan di tempat lainnya. Pesan di GrabFood/GoFood',
#  'Kamu kuat pedes ? Masa ? Kamu bukan pencinta pedas kalau belum coba Seblak Meletup!',
#  'Kelembutan mienya bisa kamu rasakan di setiap tarikannya. Pesan sekarang sebelum kehabisan',
#  'Cuma di sini kamu bisa mendapatkan sate yang 100% ayam, tanpa kulit, tanpa lemak. Yang ada cuma kamu dan daging super empuk',
#  'Bebek Madura Cak Mus bikin kamu nambah terus. Cita rasa bumbu khas Madura buat hati jadi gembira. Beli sekarang juga',
#  'Cita rasa nusantara yang bisa kamu rasakan dimana saja. Nasi Goreng Nusantara kini tersedia di seluruh Indonesia',
# ...

# %% [markdown]
# ### Scrapping Web Kedua

# %%
update_promo_page_second = bs4(promo_page_second, "lxml")
ol_html = update_promo_page_second.find_all('ol')
words = [word.find_all('li', {"class": None}) for word in ol_html]
words
# Out:
# [[<li>Beli produk elektronik di toko kami, pasti dijamin asli no tipu-tipu! Garansi hingga 2 tahun.</li>,
#   <li>Segera beli TV LED 32 inci, dapatkan voucher senilai Rp 500.000 untuk 10 orang pertama.</li>,
#   <li>Beli baju di toko kami, gratis ongkir ke seluruh Indonesia!</li>,
#   <li>Promo Menarik! Jam tangan digital hanya Rp 199.000 saja. Promo ini berlaku 1-3 September 2021.</li>,
#   <li>Tukar tambah HP lama kamu, dan dapatkan diskon hingga 30%.</li>,
#   <li>Miliki segera rumah di kawasan Depok, harga mulai Rp 300 jutaan saja!</li>,
#   <li>Promo akhir tahun! Beli 3 gratis 2 untuk seluruh pakaian di Clothing Store.</li>,
#   <li>Awas nagih! Beli 3 barang cukup bayar 1 saja. Promo berlaku dari 1-15 Juli 2022.</li>,
#   <li>Promo Lebaran! Beli 2 baju gamis gratis 1 sarung.</li>,
#   <li>Pakai moisturizer A, dijamin kulit cerah dan berseri!</li>],
#  [<li>Jangan lupa cek Instagram kita dan dapatkan cashback hingga 30%.</li>,
# ...

# %% [markdown]
# ### Pembersihan Data Web Kedua

# %%
# Extracting Words
word_result = []
for items in words:
    cleaned_words = [item.text for item in items if item.text not in unneeded_words]
    for one_word in cleaned_words:
        word_result.append(one_word)

# Result
word_result
# Out:
# ['Beli produk elektronik di toko kami, pasti dijamin asli no tipu-tipu! Garansi hingga 2 tahun.',
#  'Segera beli TV LED 32 inci, dapatkan voucher senilai Rp 500.000 untuk 10 orang pertama.',
#  'Beli baju di toko kami, gratis ongkir ke seluruh Indonesia!',
#  'Promo Menarik! Jam tangan digital hanya Rp 199.000 saja. Promo ini berlaku 1-3 September 2021.',
#  'Tukar tambah HP lama kamu, dan dapatkan diskon hingga 30%.',
#  'Miliki segera rumah di kawasan Depok, harga mulai Rp 300 jutaan saja!',
#  'Promo akhir tahun! Beli 3 gratis 2 untuk seluruh pakaian di Clothing Store.',
#  'Awas nagih! Beli 3 barang cukup bayar 1 saja. Promo berlaku dari 1-15 Juli 2022.',
#  'Promo Lebaran! Beli 2 baju gamis gratis 1 sarung.',
#  'Pakai moisturizer A, dijamin kulit cerah dan berseri!',
#  'Jangan lupa cek Instagram kita dan dapatkan cashback hingga 30%.',
#  'Cukup follow dan tag Instagram kami, free 1 nasi goreng ayam spesial + es teh manis!',
# ...

# %% [markdown]
# ### Scrapping Web Ketiga

# %%
update_promo_page_third = bs4(promo_page_third, "lxml")
promo_word_third = update_promo_page_third.find_all('span', {"class": None, "style": "font-weight: 400;"})
promo_word_third
# Out:
# [<span style="font-weight: 400;">Jika Anda memiliki bisnis makanan dan ingin selalu laris manis, maka promosikan bisnis Anda dengan kata kata promosi makanan yang menarik pelanggan. Sehingga </span>,
#  <span style="font-weight: 400;">Promosi memang sangat berperan penting dalam sebuah bisnis, karena dengan promosi maka bisnis Anda akan lebih terkenal.</span>,
#  <span style="font-weight: 400;">Sementara itu, meskipun memerlukan banyak uang untuk melakukan promosi namun dampak dari promosi sangat besar. </span>,
#  <span style="font-weight: 400;">Oleh karena itu, jangan sampai salah dalam melakukan promosi, apalagi menggunakan kalimat yang tidak menarik.</span>,
#  <span style="font-weight: 400;">Jadi, jika Anda ingin mempromosikan bisnis makanan Anda, gunakan kata kata promosi makanan berikut ini.</span>,
# ...

# %% [markdown]
# ### Pembersihan Web Ketiga

# %%
third_result = [promo_third.text for promo_third in promo_word_third if promo_third.text not in unneeded_words]
third_result
# Out:
# ['Jika Anda memiliki bisnis makanan dan ingin selalu laris manis, maka promosikan bisnis Anda dengan kata kata promosi makanan yang menarik pelanggan. Sehingga ',
#  'Promosi memang sangat berperan penting dalam sebuah bisnis, karena dengan promosi maka bisnis Anda akan lebih terkenal.',
#  'Sementara itu, meskipun memerlukan banyak uang untuk melakukan promosi namun dampak dari promosi sangat besar. ',
#  'Oleh karena itu, jangan sampai salah dalam melakukan promosi, apalagi menggunakan kalimat yang tidak menarik.',
#  'Jadi, jika Anda ingin mempromosikan bisnis makanan Anda, gunakan kata kata promosi makanan berikut ini.',
#  'Dengan menggunakan rangkaian kata promosi makanan yang menarik, dapat membuat calon pembeli lebih tertarik membeli saat melihat promosi tersebut. Berikut adalah contoh kata-kata promosi jualan makanan yang bisa Anda gunakan:',
#  '“',
#  'Dana tipis tapi pengen jajan makanan enak? Langsung aja cus beli (Nama produk anda).”',
# ...

# %% [markdown]
# ### Scrapping Web Keempat

# %%
update_promo_page_fourth = bs4(promo_page_fourth, "lxml")
promo_word_fourth = update_promo_page_fourth.find_all('li', {"class": None})
promo_word_fourth
# Out:
# [<li>Promo Kemerdekaan. Beli 5 porsi gratis 1 porsi. Stok terbatas!</li>,
#  <li>Diskon 25% <em>all </em>menu, berlaku hari ini saja!</li>,
#  <li>Promo! Beli 2 cup Boba Brown Sugar, gratis 1 cup. Khusus untuk 100 orang pertama!</li>,
#  <li>Promo Februari! Diskon 10% sepanjang bulan Februari. Diskon 100% khusus untuk tanggal 29 Februari.</li>,
#  <li>Khusus pesan antar. Beli 3 porsi bakso mercon gratis 1 porsi bakso biasa. Buruan order sekarang, jangan mau keduluan mantan!</li>,
#  <li>Diskon khusus Valentine! Makan sendiri diskon 25%. Diskon tidak berlaku buat yang bawa pasangan.</li>,
#  <li>Khusus yang suka ngemil dan nggak suka sama doi, basreng Cak Imin kini diskon 10%. Bawa pulang sekarang juga!</li>,
#  <li>Penawaran spesial makan di tempat bareng pacar, gratis minum bebas pilih. Yang jomlo mending<em> take away </em>aja.</li>,
# ...

# %% [markdown]
# ### Pembersihan Web Keempat

# %%
fourth_result = [promo_fourth.text for promo_fourth in promo_word_fourth if promo_fourth.text not in unneeded_words]
fourth_result
# Out:
# ['Promo Kemerdekaan. Beli 5 porsi gratis 1 porsi. Stok terbatas!',
#  'Diskon 25% all menu, berlaku hari ini saja!',
#  'Promo! Beli 2 cup Boba Brown Sugar, gratis 1 cup. Khusus untuk 100 orang pertama!',
#  'Promo Februari! Diskon 10% sepanjang bulan Februari. Diskon 100% khusus untuk tanggal 29 Februari.',
#  'Khusus pesan antar. Beli 3 porsi bakso mercon gratis 1 porsi bakso biasa. Buruan order sekarang, jangan mau keduluan mantan!',
#  'Diskon khusus Valentine! Makan sendiri diskon 25%. Diskon tidak berlaku buat yang bawa pasangan.',
#  'Khusus yang suka ngemil dan nggak suka sama doi, basreng Cak Imin kini diskon 10%. Bawa pulang sekarang juga!',
#  'Penawaran spesial makan di tempat bareng pacar, gratis minum bebas pilih. Yang jomlo mending take away aja.',
#  'Katanya sih jual makanan enaknya bisa dimakan sendiri. Tapi, aku jual Soto Ayam belum pernah kebagian soto buatan sendiri. Alhamdulillah…',
# ...

# %% [markdown]
# ### Scrapping Web Kelima

# %%
update_promo_page_fifth = bs4(promo_page_fifth, "lxml")
promo_word_fifth = update_promo_page_fifth.find_all('p', {"class": None})
promo_word_fifth
# Out:
# [<p><b>Bola.com, Jakarta -</b> <strong><a href="https://www.bola.com/tag/kata-kata" rel="nofollow">Kata-kata</a></strong> promosi sangat penting untuk diperhatikan. Sebab promosi merupakan satu di antara cara efektif untuk menarik para pelanggan atau konsumen, khususnya bagi seseorang yang ingin terjun ke dunia bisnis.</p>,
#  <p>Bagi pelaku bisnis, promosi menjadi andalan utama untuk memperkenalkan dan memasarkan produk-produknya. Itulah mengapa, sebuah iklan harus dibuat menarik, informatif, jelas serta memakai kata-kata yang bersifat ajakan.</p>,
#  <p>Dengan promosi yang menarik, produkmu akan mendapat atensi dari masyarakat. Jadi, sebisa mungkin dalam mempromosikan produk harus menonjolkan informasi utama dan tidak perlu terlalu bertele-tele.</p>,
#  <p>Bagi orang yang akan berkecimpung di dunia bisnis, tak boleh sembarangan dalam memuat promosi produk. Sebab, kesalahan dalam membuat promosi bisa membuat konsumen tidak percaya dengan produk yang kamu jual.</p>,
# ...

# %% [markdown]
# ### Pembersihan Web Kelima

# %%
fifth_result = [promo_fifth.text for promo_fifth in promo_word_fifth if promo_fifth.text not in unneeded_words]

# Removing Number
fifth_final_result = []

# Update Words
for target in fifth_result:
    fifth_final_result.append((target.split(". ", )[1].replace('"', "")))

# Result
fifth_final_result
# Out:
# ['Ayo beli produk kami karena yang lain belum tentu berkualitas.',
#  'Ketika kamu mengalami masalah, kami ada solusinya.',
#  'Kamu tahu apa yang menjadi kebanggaan kami? Yaitu kepuasan Anda!',
#  'Setelah memakai produk kami, jangan lupa untuk memberikan testimoni positif.',
#  'Kami besar dengan kepercayaan pelanggan dan kami memiliki visi untuk mengembangan produk kami hingga ke luar negeri.',
#  'Kami hadir untuk penawaran yang lebih besar',
#  'Perut keroncongan di tanggal tua? Segera datang ke outlet kami!',
#  'Kamu butuh catering dengan harga murah untuk acara kamu? Outlet kami solusinya!',
#  'Bingung mau makan enak di mana? Hubungi 23449 dan dapatkan berbagai menu terbaru dari kami.',
#  'Halo agan dan sista silahkan datang ke warung',
#  'Bingung mau cari minuman hits kekinian yang super higienis? Bebas bahan pengawet dan praktis? Kami solusinya!',
#  'Cari minuman kekinian yang enak, tapi tidak menguras kantong? Yuk, datang ke cafe kece kami saja kaka!',
# ...

# %% [markdown]
# ### Scrapping Web Keenam

# %%
update_promo_page_sixth = bs4(promo_page_sixth, "lxml")
promo_word_sixth = update_promo_page_sixth.find_all('li', {"class": None})
promo_word_sixth
# Out:
# [<li><a href="https://www.merdeka.com/trending/">TRENDING</a></li>,
#  <li><a href="https://www.merdeka.com/peristiwa/">NEWS</a></li>,
#  <li><a href="https://www.merdeka.com/cek-fakta/">CEK FAKTA</a></li>,
#  <li><a href="https://www.merdeka.com/uang/">EKONOMI</a></li>,
#  <li><a class="new-feature" href="https://www.merdeka.com/perbankan/">PERBANKAN</a></li>,
#  <li><a href="https://www.merdeka.com/dunia/">DUNIA</a></li>,
#  <li><a class="new-feature" href="https://www.merdeka.com/histori/">HISTORI</a></li>,
#  <li><a href="https://story.merdeka.com/">STORIES</a></li>,
#  <li><a href="https://www.merdeka.com/khas/">KHAS</a></li>,
#  <li><a href="https://www.merdeka.com/artis/">ARTIS</a></li>,
#  <li><a href="https://www.merdeka.com/video">VIDEO</a></li>,
#  <li><a href="https://www.merdeka.com/gaya/">GAYA</a></li>,
#  <li><a href="https://www.merdeka.com/teknologi/">TEK</a></li>,
#  <li><a href="https://www.merdeka.com/sehat/">SEHAT</a></li>,
# ...

# %% [markdown]
# ### Pembersihan Web Keenam

# %%
sixth_result = [promo_sixth.text for promo_sixth in promo_word_sixth if promo_sixth.text not in unneeded_words]

# Removing Number
sixth_final_result = []

# Update Words
for target in sixth_result:
    half_clean = target.replace('“', "")

    sixth_final_result.append(half_clean.replace("”", ""))

# Result
sixth_final_result
# Out:
# ['Segera beli case HP lucu ini sebelum kehabisan!',
#  'Mari lengkapi koleksi novel ini sekarang juga dan rasakan keseruan ceritanya!',
#  'Gratis es kopi susu untuk setiap pembelian botol minum eksklusif!',
#  'Diskon 70% untuk semua produk khusus di Bulan Ramadhan!',
#  'Segera kumpulkan koleksi terbarunya!',
#  'New arrival dan limited edition! Yuk segera dibeli!',
#  'Sabun cuci muka ini dijamin paling aman untuk kulit sensitif berjerawat!',
#  'Lulur Bali berkualitas terbaik dan dijamin cepat meratakan warna kulit belang Anda.',
#  'Yuk segera di-order! Free ongkir untuk Denpasar dan Jimbaran!',
#  'Hanya di sini! Toko fashion terlengkap dan termurah se Indonesia!',
#  'Lagi cari kemeja koleksi terbaru harga murah? Di sini tempatnya!',
#  'Waktu terbatas! Beli 1 gratis 1 tanpa minimum pembelian.',
#  'Lebih hemat! Beli 2 item dapatkan diskon 50% untuk produk kedua!',
#  'Barang limited edition! Pesan sebelum habis!',
# ...

# %% [markdown]
# ### Scrapping Web Ketujuh

# %%
update_promo_page_seventh = bs4(promo_page_seventh, "lxml")
promo_word_seventh = update_promo_page_seventh.find_all('p', {"class": None})
promo_word_seventh
# Out:
# [<p><b>Kapanlagi Plus</b> - Seiring berkembangnya zaman ada beragam cara mempromosikan usaha baik dalam bentuk jasa ataupun produk dengan memanfaatkan kecanggihan teknologi. Cara ini dinilai efektif menarik konsumen dengan membranding menggunakan foto, video ataupun kata-kata. Untuk itulah sejumlah <a class="dofollow" href="https://plus.kapanlagi.com/45-kata-kata-promosi-singkat-dan-lucu-menarik-perhatian-cocok-untuk-iklan-di-media-sosial-2ab718.html">kumpulan kata-kata promosi</a> yang kreatif bisa dijadikan referensi untuk menarik perhatian pelanggan.</p>,
#  <p>Promosi adalah kegiatan utama yang dilakukan setiap perusahaan agar usahanya bisa dikenal luas masyarakat. Saking pentingnya promosi, sejumlah perusahaan memperkerjakan seorang ahli khusus di bidang tersebut mulai dari jabatan marketing hingga content creator. Sebab tujuan promosi adalah untuk memasarkan, memperkenalkan, dan menawarkan produk melalui pesan yang menarik.</p>,
# ...

# %% [markdown]
# ### Pembersihan Web Ketujuh

# %%
seventh_result = [promo_seventh.text for promo_seventh in promo_word_seventh if promo_seventh.text not in unneeded_words]

# Removing Number
seventh_final_result = []

# Update Words
for target in seventh_result:
    seventh_final_result.append((target.split(". ")[1].replace('"', "")))

# Result
seventh_final_result
# Out:
# ['Ketika kamu mengalami masalah, kami ada solusinya.',
#  'Setelah memakai produk kami, jangan lupa untuk memberikan testimoni positif.',
#  'Perut keroncongan di tanggal tua? Segera datang ke outlet kami!',
#  'Bingung mau cari minuman hits kekinian yang super higienis? Bebas bahan pengawet dan praktis? Kami solusinya!',
#  'Terima kasih sudah membeli',
#  'Ingin beli kosmetik dengan harga murmer? Cek profil kita sis untuk mendapatkan info lebih lanjut!',
#  'Kesempatan terbatas, cuma hari ini! Promo sampai 80 persen gila gilaan, hanya di toko kami.',
#  'Sensasi pedas dari sambalnya siap membakar lidah Anda',
#  'Peringatan! Keripik ini dapat menyebabkan Anda kesulitan berhenti mengunyah.',
#  'Ingin makan gratis? Post fotomu bersama menu favoritmu di warung kami.',
#  'Dapatkan perut bebas buncit dengan konsumsi bubur oat kami.',
#  'Heboh, promo paket hemat besar-besaran jelang lebaran!',
#  'Susu pesanan Anda akan aman kurir kami antar sampai ke tempat tujuan.',
# ...

# %% [markdown]
# ### Scrapping Web Kedelapan

# %%
update_promo_page_eigth = bs4(promo_page_eigth, "lxml")
promo_word_eigth = update_promo_page_eigth.find_all('p', {"class": None})
promo_word_eigth
# Out:
# [<p><strong><a href="https://www.intipseleb.com/tag/intipseleb-gaya-hidup">IntipSeleb Gaya Hidup</a></strong> – Kumpulan kata-kata promosi sangat bermanfaat untuk menarik perhatian pelanggan agar tertarik untuk membeli produk yang kita jual. Mengetahui kata-kata promosi tersebut penting apalagi untuk yang baru memulai sebuah <a href="https://www.intipseleb.com/tag/bisnis">bisnis</a>.</p>,
#  <p>Saat memutuskan untuk menjalankan sebuah bisnis, bukan hanya aspek seberapa bagus produk atau jasanya saja yang penting untuk diperhatikan, namun seberapa baik promosi yang dilakukan juga harus dipersiapkan.</p>,
#  <p>Karena dengan promosi yang menarik, tentu produk atau jasa yang ditawarkan mampu membuat masyarakat tak ragu untuk mencoba.</p>,
#  <p>Nah, berikut ini adalah daftar kumpulan kata-kata promosi yang bisa menjadi inspirasi bagi Anda pelaku usaha yang membutuhkan kata-kata menarik untuk keperluan promosi. Yuk, cek selengkapnya!</p>,
# ...

# %% [markdown]
# ### Pembersihan Web Kedelapan

# %%
eigth_result = [promo_eigth.text for promo_eigth in promo_word_eigth if promo_eigth.text not in unneeded_words]

# Removing Number
eigth_final_result = []

# Update Words
for target in eigth_result:
    half_clean = target.replace('“', "")

    eigth_final_result.append((half_clean.split(". ")[1].replace('”', "")))

# Result
eigth_final_result
# Out:
# ['Bingung mau cari minuman hits dan kekinian yang super enak dan higienis? Suka yang bebas bahan pengawet dan praktis? Kamilah solusinya!',
#  'Jangan ragu, segera dapatkan produk, kami, dijamin kualitasnya!',
#  'Kalau perut lapar jangan ditahan, segera datang ke gerai kami dan dapatkan produk makanan terbaik!',
#  'Bingung mau makan di mana? Yuk, segera pesan ayam dari kami yang banyak pilihannya!',
#  'Bukan abal-abal, kami hanya menjual segala produk dengan bahan berkualitas dan bergaransi panjang',
#  'Takut dapat barang palsu? Jangan khawatir, hanya di sini kamu akan mendapatkan 100% barang asli, no tipu-tipu! Terbukti barang tidak asli, langsung kami ganti!',
#  'Jangan ragu beli produk kami, sudah pasti berkualitas tinggi dan nggak akan bikin kecewa!',
#  'Perut keroncongan terus tapi kini sudah tanggal tua? Segera datang ke outlet kami',
#  'Klaim garansi kamu sekarang dan dapatkan layanan service gratis untuk semua produk elektronik yang kamu beli di toko kami.',
# ...

# %% [markdown]
# ### Scrapping Web Kesembilan

# %%
update_promo_page_ninth = bs4(promo_page_ninth, "lxml")
promo_word_ninth = update_promo_page_ninth.find_all('p', {"class": None})
promo_word_ninth
# Out:
# [<p><b>Merdeka.com - </b> <a href="https://www.merdeka.com/tag/kata-mutiara/">Kata-kata promosi makanan</a> harus diperhatikan. Sebab promosi merupakan salah satu cara efektif untuk menarik para pelanggan ataupun konsumen, khususnya bagi Anda yang memutuskan untuk terjun ke dunia bisnis menjual produk makanan.</p>,
#  <p>Bagi pengusaha, laku kerasnya suatu produk yang dijual tentu akan menjadi pencapaian begitu membanggakan. Salah satu dari banyak cara yang bisa digunakan untuk mewujudkan semua itu adalah dengan memperhatikan <a href="https://www.diadona.id/d-stories/30-contoh-kata-promosi-jualan-makanan-di-instagram-dan-media-sosial-lainnya-yang-menarik-2102167.html" target="_blank">kata-kata promosi</a> terlebih dahulu sebagai strategi pemasarannya.</p>,
# ...

# %% [markdown]
# ### Pembersihan Web Kesembilan

# %%
ninth_result = [promo_ninth.text for promo_ninth in promo_word_ninth if promo_ninth.text not in unneeded_words]

# Removing Number
ninth_final_result = []

# Update Words
for target in ninth_result:
    half_clean = target.replace('“', "")

    ninth_final_result.append((half_clean.split(". ")[1].replace('”', "")))

# Result
ninth_final_result
# Out:
# ['Ayam geprek tidak pedas, garansi 100% uang kembali!',
#  'Segera rasakan sensasi pedasnya sebelum kehabisan!',
#  'Hanya dengan membeli menu senilai Rp 50.000 kamu bisa dapat gratis es teler!',
#  'Aroma kaldu sapi bakso kami siap menggugah selera Anda!',
#  'Keripik kemasan 500 gram ini sudah tersedia di seluruh Indonesia.',
#  'Tempura ini satu-satunya produk frozen food yang 100% bebas boraks.',
#  'Dapatkan promo gratis jus melon khusus hari ini, hemat sampai Rp 20.000.',
#  'Dapatkan perut bebas buncit dengan konsumsi bubur oat kami.',
#  'Susu pesanan Anda akan aman kurir kami antar sampai ke tempat tujuan.',
#  'Heboh, promo paket hemat besar-besaran jelang lebaran!',
#  'Madu asli langsung dari sarangnya.',
#  'Cukup membayar seikhlasnya, dapatkan paket komplit ini!',
#  'Buy 2 Get 1 Free, beli 2 paket nasi ayam gratis 1 cup es teh manis.',
#  'Sensasi pedas dari sambalnya siap membakar lidah Anda',
#  'Diskon hingga 50% khusus produk keripik rasa keju jagung.',
# ...

# %% [markdown]
# ### Scrapping Web Kesepuluh

# %%
update_promo_page_tenth = bs4(promo_page_tenth, "lxml")
promo_word_tenth = update_promo_page_tenth.find_all('li', {"class": None})
promo_word_tenth
# Out:
# [<li>Cuaca mendung hujan gini lur,cocok banget buat nikmatin yang pedas panas lurr.. Aq rekomendasi in entok petir buat nemenin makan kamu lurr..Sensasi pedas melintir bikin nagih pokok e lurr.. Kami tunggu ya lurr.. (Enthok Petir).</li>,
#  <li>Menu Baru Racikan Bang Jergo!😋 Kenalkan nih Empal Jagoan!!! Diolah dari beef shank impor,so gausah ditanya tingkat keempukan nya. Juga rasa nya yang gurih dan manis pasti memberi kenangan yang berbeda untuk para Konco Jero. Ditambah kuah rempah yang asoy ketika diseruput, di padu padan kan dengan pilihan aneka sambal yang Bang Jergo siapkan.. Yaudah bang Jergo tunggu ya di warung Spesial Jeroan Sapi Ter -enak Sejagat. (Jeroan Jagoan Jogja).</li>,
# ...

# %% [markdown]
# ### Pembersihan Web Kesepuluh

# %%
tenth_result = [promo_tenth.text for promo_tenth in promo_word_tenth if promo_tenth.text not in unneeded_words]

# Result
tenth_result
# Out:
# ['Cuaca mendung hujan gini lur,cocok banget buat nikmatin yang pedas panas lurr.. Aq rekomendasi in entok petir buat nemenin makan kamu lurr..Sensasi pedas melintir bikin nagih pokok e lurr.. Kami tunggu ya lurr.. (Enthok Petir).',
#  'Menu Baru Racikan Bang Jergo!😋 Kenalkan nih Empal Jagoan!!! Diolah dari beef shank impor,so gausah ditanya tingkat keempukan nya. Juga rasa nya yang gurih dan manis pasti memberi kenangan yang berbeda untuk para Konco Jero. Ditambah kuah rempah yang asoy ketika diseruput, di padu padan kan dengan pilihan aneka sambal yang Bang Jergo siapkan.. Yaudah bang Jergo tunggu ya di warung Spesial Jeroan Sapi Ter -enak Sejagat. (Jeroan Jagoan Jogja).',
# ...

# %% [markdown]
# ### Scrapping Web Kesebelas

# %%
update_promo_page_eleventh = bs4(promo_page_eleventh, "lxml")
promo_word_elevnth = update_promo_page_eleventh.find_all('li', {"class": None})
promo_word_elevnth
# Out:
# [<li><form action="https://portal-uang.com/" class="search-header-form" method="get"> <input class="search-input" name="s" onblur="(this.value == '') &amp;&amp; (this.value = 'Pencarian...')" onfocus="(this.value == 'Pencarian...') &amp;&amp; (this.value = '')" placeholder="Pencarian..." size="20" type="text" value="Pencarian..."/> </form></li>,
#  <li>Puasin laper lo, pasin muda lo!</li>,
#  <li>Hits abis!</li>,
#  <li>Baru! Pop Mie Goreng rasa sosis</li>,
#  <li>Bikinnya bener, rasanya puas bener!</li>,
#  <li>Lebih besar, lebih sedap!</li>,
#  <li>Ditambah taburan toping yang seru!</li>,
#  <li>Awas nagih!</li>,
#  <li>Pedes dower rasanya!</li>,
#  <li>Pedesnya bikin nagih!</li>,
#  <li>Puas pedesnya!</li>,
#  <li>Puasin serunya liburan Pop Mie lo!</li>,
#  <li>Baso soto, cuy!</li>,
#  <li>Suwar-suwir ayam gorengnya!</li>,
#  <li>Dengan kriuk kacang asli!</li>,
#  <li>Lengkap dengan pilus!</li>,
#  <li>Gurih!</li>,
#  <li>Lezat dan nikmat!</li>,
#  <li>Praktis dan ekonomis!</li>,
# ...

# %% [markdown]
# ### Pembersihan Web Kesebelas

# %%
eleventh_result = [promo_eleventh.text for promo_eleventh in promo_word_elevnth if promo_eleventh.text not in unneeded_words]

# Result
eleventh_result
# Out:
# ['Puasin laper lo, pasin muda lo!',
#  'Hits abis!',
#  'Baru! Pop Mie Goreng rasa sosis',
#  'Bikinnya bener, rasanya puas bener!',
#  'Lebih besar, lebih sedap!',
#  'Ditambah taburan toping yang seru!',
#  'Awas nagih!',
#  'Pedes dower rasanya!',
#  'Pedesnya bikin nagih!',
#  'Puas pedesnya!',
#  'Puasin serunya liburan Pop Mie lo!',
#  'Baso soto, cuy!',
#  'Suwar-suwir ayam gorengnya!',
#  'Dengan kriuk kacang asli!',
#  'Lengkap dengan pilus!',
#  'Gurih!',
#  'Lezat dan nikmat!',
#  'Praktis dan ekonomis!',
#  'Makanan nasional penuh gizi!',
#  'Semakin terasa merakyat!',
#  'Puas sedapnya!',
#  'Soal rasa, lidah tak bisa bohong!',
#  'Zuper krunch!',
#  'Kriuknya berasa banget!',
#  'Asli rasa khasnya! Mau yang praktis, hemat dan lezat? Ke sini aja!',
#  'Harga terjangkau!',
#  'Life is never flat!',
#  'Beefy, cheesy perfection quarter pounder with cheese',
#  'Menu masakan rumahan yang istimewa dan higienis!',
#  'Pilih Menu favorit Anda!',
# ...

# %% [markdown]
# ### Create Data Frame

# %%
# Combining Words
final_result = np.concatenate((result, word_result, third_result, fourth_result, fifth_final_result, sixth_final_result, seventh_final_result, eigth_final_result, ninth_final_result, tenth_result, eleventh_result))

# Showing Data Frame
words_df = pd.DataFrame(zip(final_result), columns=["Kalimat Promo"])

# Drop Duplicate
words_df_final = words_df.drop_duplicates()

# Taking Only 950
df_final = words_df_final.head(950)

# Final
df_final
# Out:
#                                           Kalimat Promo
# 0     Beli 4 ayam penyet, cuma bayar 3 setiap hari J...
# 1     Beli banyak lebih hemat! Diskon sampai 35% den...
# 2     Yuk bunda siapkan berbagai Frozen Food dari Ra...
# 3     Rasa masakan Padang yang tidak pernah kamu tem...
# 4     Kamu kuat pedes ? Masa ? Kamu bukan pencinta p...
# ...                                                 ...
# 1013                                 Friday is Freeday!
# 1014                    Family package only Rp150.000,-
# 1015                        Lunch crase onlu Rp49.000,-
# 1016                        Frech fries only Rp20.000,-
# 1017                        Salmon skin only Rp20.000,-
#
# [950 rows x 1 columns]

# %% [markdown]
# ### Export Data

# %%
# Nama File
file_name = 'Words.xlsx'

# saving the excel
df_final.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
